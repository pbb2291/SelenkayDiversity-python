# %% [markdown]
# ### Outputting Grid Metrics as 2D and 3D Arrays
# ***Lidar-Notebooks***<br>
# *PB* <p>
# 2022/11/29 <p>
#
# <p>This is the third step in a 3 part process for 1) clipping las files with a set of polygons (1-ClipLasWithPolygonsforVoxels.ipynb); 2) voxeling lidar data, computing vegetation structure metrics, and outputting a pickle file (2-ProcessVoxelMetrics.ipynb); and 3) outputting the pixel and voxel grids of each metric as geotif or netcdf files for use in qgis and other software (3-OutputVoxelMetrics_Geotiff_NetCDF.ipynb). </p>

# %%
import sys
sys.path.append('/n/home02/pbb/scripts/halo-metadata-server/LabLidarScripts/bin/')
# sys.path.append('../../bin/')
from LabLidar_Functions import fill2Darray, classifyVeg_GGW, classifyVeg_GGST
import matplotlib.pyplot as plt
import numpy as np
import pickle
import pandas as pd
import rasterio as rio
import xarray as xr
import rioxarray as rxr
from pathlib import Path
import geopandas as gpd
import time
import laspy
from shapely.geometry import Polygon

# %%
# # # USER INPUTS: 

# Input Data:

# Working directory
wd = '/n/davies_lab/Users/pbb/SelenkayDiversity/data/PredictionSite01'

# Set the pickle metrics to draw from
# metricdir = Path('/n/davies_lab/Users/pbb/SelenkayDiversity/data/PredictionTransect/metrics/')
metricdir = Path(wd + '/metrics/')

# Horizontal Grid size
xysize = 0.5

# Ground threshold
groundthreshold = 0.05

# Set CRS of las files
# Kruger is 32736 (WGS84 UTM 36S)
# Mpala is 32637 (WGS84 UTM 37N)
# Selenkay is 32737 (WGS84 UTM37S)
epsg='32737'

# Shapefile of Plots
# Note: Should be same shapefile as in Step 1-ClipLasWithPolygons
# shpf = Path('/n/davies_lab/Users/pbb/SelenkayDiversity/data/PredictionTransect/shapefile/PredictionTransect_260mGrid_EPSG32737.shp')
shpf = Path(wd + '/shapefile/Prediction_SelenkaySite01_260mGrid_Intersection.shp')

shpdf = gpd.read_file(shpf)

featureIDcol = 'id'

# Output Data:

# Outdirectory for rasters and netcdfs
# outdir_rast = Path('/n/davies_lab/Users/pbb/SelenkayDiversity/data/PredictionTransect/grid_metrics')
outdir_rast = Path(wd + '/grid_metrics')

# # #  END USER INPUTS

# %%
# list of 3D metrics to output,
# corresponding to the names in the saved cover dictionaries
# Note: all percentile metrics get output by default
metriclabels3d = ['Npulses', 'CoverD1', 'CoverD2', 'CoverD1byH', 'CoverD2byH', 'FHPD1', 'FHPD2']

# %%
# Addition for Selenkay - 
# only loop through blocks that have metrics in the metric folder
Sites = [int(str(p).split('_')[3]) for p in metricdir.glob('*.json')]
# Sites[0:10]

# Old way:
# Sites to loop through
# Sites = [s for s in shpdf[featureIDcol]]
# Out:
# [151, 296, 180, 153, 411, 246, 150, 443, 220, 247]

# %%
# New addition for Selenkay Predictions: 4/19/23
# make a dictionary to save important model metrics to a shapefile
modelmetric_dict = {'id':[],
                    'mean_gapsize':[],
                    'sd_gapsize':[]}
                    # 'sd_CD_AboveG':[],
                    # 'cv_FHD':[],
                    # 'mean_stdpeakh':[]

# For each site/file name
for s in Sites:

    start = time.time()
    
    # Get organized:
    # make output folders, as subdirectories for each file/site
    # if they don't exist yet
    if not Path(f'{outdir_rast}/{s}/').exists():
        Path(f'{outdir_rast}/{s}/').mkdir()

    # 1) Load Inputs, and Redefine Grid

    # Load percentile height metric dict
    with open(f'{metricdir}/{featureIDcol}_{s}_{xysize}mgrid_percmetrics.obj', 'rb') as of:
        perc = pickle.load(of)

    # Load Cover percentile dict
    with open(f'{metricdir}/{featureIDcol}_{s}_{xysize}mgrid_covermetrics.obj', 'rb') as of:
        cover = pickle.load(of)
        
    # Load Complexity dict
    with open(f'{metricdir}/{featureIDcol}_{s}_{xysize}mgrid_complexitymetrics.obj', 'rb') as of                                                                                                                                                                                                                                                                                                                                    :
        complexity = pickle.load(of)
    
    # Match site to get the plot polygon
    feat_gs = shpdf.loc[shpdf[featureIDcol]==s]

    # Set bounds of grid to fill
    xmin=float(feat_gs.geometry.bounds.minx)
    ymin=float(feat_gs.geometry.bounds.miny)
    xmax=float(feat_gs.geometry.bounds.maxx)
    ymax=float(feat_gs.geometry.bounds.maxy)

    # Make the coordinates of the grid
    x_grid = np.arange(xmin, xmax, step=xysize)
    y_grid = np.arange(ymin, ymax, step=xysize)

    # Mesh the grid into 2 matrices of x and y coordinates
    x_mesh, y_mesh = np.meshgrid(x_grid, y_grid)

    # Find the index of where all the data values belong in the grid
    xlist = [k[0] for k in cover.keys()]
    ylist = [k[1] for k in cover.keys()]

    xidx = []
    yidx = []

    # for each unique x,y location in the list of data values
    for x, y in zip(xlist, ylist):

        # # Find it's unique x and y index location on the grid (ex: [0,1], [100,3], ...)        
        # xi = np.flatnonzero(x_grid==x)
        # yi = np.flatnonzero(y_grid==y)
        
       # Note: implemented the below, because I think there's a rounding error issue
       # grid x_grid and xlist don't quite match, off by about 0.009 m
       # 10/18/22
        
        # Find the closest value on the grid to make the index
        # calculate the difference array
        xdiff = np.absolute(x-x_grid)
        # find the index of minimum element from the array
        xindex = xdiff.argmin()
        
        # calculate the difference array
        ydiff = np.absolute(y-y_grid)
        # find the index of minimum element from the array
        yindex = ydiff.argmin()
        
        xi = np.flatnonzero(x_grid==x_grid[xindex])
        yi = np.flatnonzero(y_grid==y_grid[yindex])

        # If there is a location (not empty)
        if ((xi.size > 0) & (yi.size > 0)):

            # Add to the list
            xidx.append(xi[0])
            yidx.append(yi[0])

        else: 

            # Otherwise, mark them both with nans
            xidx.append(np.nan)
            yidx.append(np.nan)
    
    
    # 2) Load, Reshape, and Output 2D Metrics

    # Get all the data dicts from the nested perc dictionary
    v = list(perc.values())

    # unpack all vars into lists
    perc0 = [i[0][0] for i in v]
    perc25 = [i[25][0] for i in v]
    perc50 = [i[50][0] for i in v]
    perc75 = [i[75][0] for i in v]
    perc98 = [i[98][0] for i in v]
    perc100 = [i[100][0] for i in v]
    meanh = [i['mean'][0] for i in v]
    stdh = [i['std'][0] for i in v]
    
    # Classify Vegetation using 98th percentile height
    vegtypeGGST = [classifyVeg_GGST(p, groundthreshold=groundthreshold) for p in perc98]
    vegtypeGGW = [classifyVeg_GGW(p, groundthreshold=groundthreshold) for p in perc98]
    
    # Get all the data vals from the nested complexity dictionary
    vc = list(complexity.values())

    # unpack all vars into lists
    nlayers = [i['nlayers'] for i in vc]
    maxpeakh = [i['maxpeakh'] for i in vc]
    gapsize = [i['gapsize'] for i in vc]
    ptoh = [i['ptoh'] for i in vc]
    cscore = [i['cscore'] for i in vc]
    FHD = [i['FHD'] for i in vc]
    VDR = [i['VDR'] for i in vc]
    meanpeakh = [i['meanpeakh'] for i in vc]
    stdpeakh = [i['stdpeakh'] for i in vc]
    cvpeakh = [i['cvpeakh'] for i in vc]
    VDRpeak = [i['VDRpeak'] for i in vc]
    herbh = [i['herbh'] for i in vc]



    # Reshape vars into 2D arrays and store in a dictionary
    outdict = {}.fromkeys(['0th','25th', '50th', '75th', '98th', '100th', 'Mean', 'Std', 'vegtypeGGST', 'vegtypeGGW',
                           'nlayers', 'gapsize', 'maxpeakh','ptoh', 'cscore', 'FHD', 'VDR', 'meanpeakh', 'stdpeakh', 'cvpeakh', 'VDRpeak', 'herbh'])

    for m, l in zip([perc0, perc25, perc50, perc75, perc98, perc100, meanh, stdh, vegtypeGGST, vegtypeGGW,
                     nlayers, gapsize,maxpeakh, ptoh, cscore, FHD, VDR, meanpeakh, stdpeakh, cvpeakh, VDRpeak, herbh],
                    ['0th','25th', '50th', '75th', '98th', '100th', 'Mean', 'Std', 'vegtypeGGST', 'vegtypeGGW',
                     'nlayers', 'gapsize', 'maxpeakh','ptoh', 'cscore', 'FHD', 'VDR', 'meanpeakh', 'stdpeakh', 'cvpeakh', 'VDRpeak', 'herbh']):

        outdict[l] = fill2Darray(data=m, shape=x_mesh.shape,
                                 xindices=xidx, yindices=yidx, plot=False)

    # Output 2D Arrays as geotifs
    for l in ['0th','25th', '50th', '75th', '98th', '100th', 'Mean', 'Std', 'vegtypeGGST', 'vegtypeGGW',
              'nlayers', 'gapsize', 'maxpeakh','ptoh', 'cscore', 'FHD', 'VDR', 'meanpeakh', 'stdpeakh', 'cvpeakh', 'VDRpeak', 'herbh']:

        # Grab one metric for output
        m = outdict[l]

        # Mirror Image the metric
        # Note: You do this because rioxarray wants data
        # ordered with positive x (left to right)
        # but with negative y (top to bottom)
        # This really just makes the export to geotif go smoothly,
        # with a correct affine transform 
        m = np.flipud(m)

        # Also flip y coordinates, so that they're correctly read into x array
        # y_grid_flip = np.flip(y_grid)
        # NOTE: adding xysize to y coord so that it marks Top left corner
        # instead of bottom left - this is in accordance with raster data and rioxarray
        y_grid_flip = np.flip(y_grid) + xysize

        # put in an xarray
        # 2D
        m_xr = xr.DataArray(data=m,
                            coords={"y": y_grid_flip,
                                    "x": x_grid},
                            dims=["y", "x"])

        # Write CRS and Nodata value and dims to xarray
        m_xr.rio.write_crs(f"epsg:{epsg}",
                           inplace=True)
        m_xr.rio.write_nodata(-9999,
                              inplace=True)
        m_xr.rio.set_spatial_dims(x_dim="x",
                                  y_dim="y",
                                  inplace=True)
        m_xr.rio.write_coordinate_system(inplace=True)

        # make an output Label
        label = l.replace(' ', '').replace('.', 'p').replace('[m]', '')

        m_xr.rio.to_raster(f'{outdir_rast}/{s}/{s}_{label}.tif')

        print(f'{l} done')

    end2d = time.time()

    print(f'Finished 2D outputs for {featureIDcol} {s}. {end2d-start} seconds. \n')

    
    # 3) Load, Reshape, and Output 3D Metrics

    # Unpack cover values as a list
    v3 = list(cover.values())

    # Get list of heights for later
    hbins = v3[0]['HeightBins']
    
    # Make shape for output array
    # note - y, then x here
    shape = (len(y_grid), len(x_grid))

    # for each set of 3D metrics
    for l3 in metriclabels3d:
        
        try:
            
            # list to fill with xarrays from each height
            xr_list = []

            # Deals with an issue caused by using np.diff
            # if there's a difference metric, then the last height does not have a value
            if (("byH" in l3) | ('FHP' in l3)) :
                hbinz = hbins[0:-1]
            else:
                hbinz = hbins

            # for each height bin
            for hidx, h in enumerate(hbinz): 

                # make an array of all the values
                m = np.array([i[l3][hidx] for i in v3])

                # make an empty output array, filled with nans
                output_array = np.full(shape, np.nan)

                # Convert to int
                xindices = np.array(xidx).astype(int)
                yindices = np.array(yidx).astype(int)

                # Fill any inf values in data with -9999
                # data[np.isfinite(data, where=False)] = -9999

                # stick into the array
                # IMPORTANT: it's y, then x, not the other way around
                output_array[yindices, xindices] = m

                # Mirror Image the metric
                # Note: You do this because rioxarray wants data
                # ordered with positive x (left to right)
                # but with negative y (top to bottom)
                # This really just makes the export to geotif go smoothly,
                # with a correct affine transform.
                output_array = np.flipud(output_array)

                # Also flip y coordinates, so that they're correctly read into x array 
                # Also, adding xysize to y coord so that it marks top left corner
                # instead of bottom left - this is in accordance with raster data and rioxarray
                y_grid_flip = np.flip(y_grid) + xysize

                # put in an xarray - 2D
                m_xr = xr.DataArray(data=output_array,
                                    coords={"y": y_grid_flip,
                                            "x": x_grid},
                                    dims=["y", "x"])

                # Write CRS and Nodata value
                m_xr.rio.write_crs(f"epsg:{epsg}", inplace=True)
                m_xr.rio.write_nodata(-9999, inplace=True)
                m_xr.rio.set_spatial_dims(x_dim="x", y_dim="y", inplace=True)
                m_xr.rio.write_coordinate_system(inplace=True)

                # add to list 
                xr_list.append(m_xr)

            # Concatenate dataarrays
            # https://docs.xarray.dev/en/stable/user-guide/combining.html#combine
            # setting the values of the new dimension to be height
            ds = xr.concat(xr_list, hbinz)
            ds = ds.rename({'concat_dim':'z'})

            # Set it's name
            ds.name = l3

            # output to netcdf
            ds.to_netcdf(f'{outdir_rast}/{s}/{s}_{l3}.nc')
        
        except Exception as e:
            
            print(f'{e.__class__} - {e}.\n\tNo file output for {l3}.')
            
    end3d = time.time()

    print(f'Finished 3D outputs for {featureIDcol} {s}. {end3d-start} seconds.\n')
    
    # Addition for selenkay 4/19/23
    # Compute important model metrics and add to dict
    # to save out as a shapefile for prediction later
    modelmetric_dict['id'].append(s)
    modelmetric_dict['mean_gapsize'].append(np.nanmean(gapsize))
    modelmetric_dict['sd_gapsize'].append(np.nanstd(gapsize))

# add model metrics to shapefile for easy access
modelmetric_df = pd.DataFrame(modelmetric_dict)
shpdf_out = shpdf.merge(modelmetric_df, on=featureIDcol)
shpdf_out.to_file(f'{outdir_rast}/ModelMetrics.shp')

print(f'\tSaved metric shapefile: {outdir_rast}/ModelMetrics.shp \n')
      
print('Done outputting files.')
# Out:
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 151. 24.614845275878906 seconds.
#
# Finished 3D outputs for id 151. 84.19355130195618 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 296. 30.088313579559326 seconds.
#
# Finished 3D outputs for id 296. 98.89933729171753 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 180. 27.753191232681274 seconds.
#
# Finished 3D outputs for id 180. 102.1819326877594 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 153. 29.495309352874756 seconds.
#
# Finished 3D outputs for id 153. 104.55988502502441 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 411. 7.551199197769165 seconds.
#
# Finished 3D outputs for id 411. 28.190419673919678 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 246. 25.456636428833008 seconds.
#
# Finished 3D outputs for id 246. 86.28623843193054 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 150. 29.397263050079346 seconds.
#
# Finished 3D outputs for id 150. 96.36006927490234 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 443. 17.97621488571167 seconds.
#
# Finished 3D outputs for id 443. 62.42663764953613 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 220. 28.241752862930298 seconds.
#
# Finished 3D outputs for id 220. 98.17466330528259 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 247. 29.82228374481201 seconds.
#
# Finished 3D outputs for id 247. 105.7818534374237 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 130. 31.15540075302124 seconds.
#
# Finished 3D outputs for id 130. 104.93373370170593 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 149. 32.8158700466156 seconds.
#
# Finished 3D outputs for id 149. 107.82405114173889 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 421. 27.28238606452942 seconds.
#
# Finished 3D outputs for id 421. 99.51926040649414 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 417. 30.207091093063354 seconds.
#
# Finished 3D outputs for id 417. 103.73423886299133 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 297. 30.888482332229614 seconds.
#
# Finished 3D outputs for id 297. 104.91813921928406 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 242. 27.789749145507812 seconds.
#
# Finished 3D outputs for id 242. 101.38269686698914 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 387. 30.66656804084778 seconds.
#
# Finished 3D outputs for id 387. 104.38592743873596 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 293. 26.85404920578003 seconds.
#
# Finished 3D outputs for id 293. 87.65171694755554 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 39. 31.966681241989136 seconds.
#
# Finished 3D outputs for id 39. 108.7674469947815 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 412. 24.91129493713379 seconds.
#
# Finished 3D outputs for id 412. 86.77243876457214 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 91. 10.556024551391602 seconds.
#
# Finished 3D outputs for id 91. 46.353649854660034 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 152. 30.390424251556396 seconds.
#
# Finished 3D outputs for id 152. 100.43684029579163 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 442. 8.404310703277588 seconds.
#
# Finished 3D outputs for id 442. 31.580169916152954 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 267. 26.046451091766357 seconds.
#
# Finished 3D outputs for id 267. 92.11218237876892 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 416. 29.04337191581726 seconds.
#
# Finished 3D outputs for id 416. 97.89365148544312 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 448. 18.984512090682983 seconds.
#
# Finished 3D outputs for id 448. 68.30418634414673 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 207. 29.911670446395874 seconds.
#
# Finished 3D outputs for id 207. 97.67458629608154 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 14. 3.318697690963745 seconds.
#
# Finished 3D outputs for id 14. 19.4870285987854 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 158. 22.22988510131836 seconds.
#
# Finished 3D outputs for id 158. 83.23173427581787 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 249. 30.101330995559692 seconds.
#
# Finished 3D outputs for id 249. 97.22412991523743 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 119. 6.500637054443359 seconds.
#
# Finished 3D outputs for id 119. 32.94725298881531 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 100. 24.210386037826538 seconds.
#
# Finished 3D outputs for id 100. 98.25698351860046 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 353. 29.856074333190918 seconds.
#
# Finished 3D outputs for id 353. 101.64644837379456 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 327. 29.673707485198975 seconds.
#
# Finished 3D outputs for id 327. 101.50380063056946 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 71. 33.38006258010864 seconds.
#
# Finished 3D outputs for id 71. 107.97049260139465 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 63. 19.126039505004883 seconds.
#
# Finished 3D outputs for id 63. 74.18858480453491 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 268. 30.40245294570923 seconds.
#
# Finished 3D outputs for id 268. 102.71398949623108 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 422. 12.898568630218506 seconds.
#
# Finished 3D outputs for id 422. 48.36902642250061 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 93. 28.281426906585693 seconds.
#
# Finished 3D outputs for id 93. 97.20353150367737 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 394. 2.292584180831909 seconds.
#
# Finished 3D outputs for id 394. 16.822412490844727 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 188. 23.082833766937256 seconds.
#
# Finished 3D outputs for id 188. 79.07118964195251 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 218. 27.629345178604126 seconds.
#
# Finished 3D outputs for id 218. 92.54022073745728 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 70. 28.597800731658936 seconds.
#
# Finished 3D outputs for id 70. 95.81110906600952 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 269. 29.934038162231445 seconds.
#
# Finished 3D outputs for id 269. 98.94230604171753 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 390. 27.476644039154053 seconds.
#
# Finished 3D outputs for id 390. 100.3765857219696 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 441. 2.861058235168457 seconds.
#
# Finished 3D outputs for id 441. 17.600788116455078 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 98. 22.830338954925537 seconds.
#
# Finished 3D outputs for id 98. 80.8126392364502 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 354. 27.420838832855225 seconds.
#
# Finished 3D outputs for id 354. 92.61833119392395 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 132. 26.74580979347229 seconds.
#
# Finished 3D outputs for id 132. 94.66861915588379 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 274. 33.99893546104431 seconds.
#
# Finished 3D outputs for id 274. 102.96981072425842 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 131. 28.980411052703857 seconds.
#
# Finished 3D outputs for id 131. 101.79734659194946 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 74. 17.050370454788208 seconds.
#
# Finished 3D outputs for id 74. 65.26173186302185 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 35. 15.083984136581421 seconds.
#
# Finished 3D outputs for id 35. 56.238598108291626 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 352. 24.503231048583984 seconds.
#
# Finished 3D outputs for id 352. 82.49621486663818 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 444. 26.082178592681885 seconds.
#
# Finished 3D outputs for id 444. 95.1134283542633 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 272. 29.44378089904785 seconds.
#
# Finished 3D outputs for id 272. 105.65225100517273 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 186. 32.57129406929016 seconds.
#
# Finished 3D outputs for id 186. 109.5670120716095 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 184. 28.36169719696045 seconds.
#
# Finished 3D outputs for id 184. 106.15953660011292 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 160. 30.7560715675354 seconds.
#
# Finished 3D outputs for id 160. 107.7784743309021 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 125. 32.520936250686646 seconds.
#
# Finished 3D outputs for id 125. 107.62308549880981 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 325. 34.74904775619507 seconds.
#
# Finished 3D outputs for id 325. 113.08342504501343 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 295. 33.320881843566895 seconds.
#
# Finished 3D outputs for id 295. 108.07162880897522 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 329. 35.204102754592896 seconds.
#
# Finished 3D outputs for id 329. 113.13480877876282 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 216. 29.460357427597046 seconds.
#
# Finished 3D outputs for id 216. 105.54287385940552 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 332. 30.752350091934204 seconds.
#
# Finished 3D outputs for id 332. 108.25968790054321 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 75. 3.1570324897766113 seconds.
#
# Finished 3D outputs for id 75. 19.097956657409668 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 381. 5.457000017166138 seconds.
#
# Finished 3D outputs for id 381. 26.942435026168823 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 178. 26.30663537979126 seconds.
#
# Finished 3D outputs for id 178. 88.34661650657654 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 445. 27.029888153076172 seconds.
#
# Finished 3D outputs for id 445. 90.5634331703186 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 362. 14.628434419631958 seconds.
#
# Finished 3D outputs for id 362. 55.39580059051514 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 209. 31.566593647003174 seconds.
#
# Finished 3D outputs for id 209. 99.33512592315674 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 162. 26.597236394882202 seconds.
#
# Finished 3D outputs for id 162. 100.97094058990479 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 294. 29.38849377632141 seconds.
#
# Finished 3D outputs for id 294. 100.81684064865112 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 92. 29.94043469429016 seconds.
#
# Finished 3D outputs for id 92. 103.65264844894409 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 219. 30.421404361724854 seconds.
#
# Finished 3D outputs for id 219. 106.08398056030273 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 159. 26.959308862686157 seconds.
#
# Finished 3D outputs for id 159. 103.2174129486084 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 389. 29.634514331817627 seconds.
#
# Finished 3D outputs for id 389. 105.09221744537354 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 277. 27.88086724281311 seconds.
#
# Finished 3D outputs for id 277. 94.34325361251831 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 128. 29.4902241230011 seconds.
#
# Finished 3D outputs for id 128. 105.57215428352356 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 90. 2.2948813438415527 seconds.
#
# Finished 3D outputs for id 90. 16.68962001800537 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 95. 22.456886291503906 seconds.
#
# Finished 3D outputs for id 95. 78.79650282859802 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 36. 26.26105809211731 seconds.
#
# Finished 3D outputs for id 36. 89.4371907711029 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 148. 14.36657428741455 seconds.
#
# Finished 3D outputs for id 148. 58.685832023620605 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 122. 28.832020044326782 seconds.
#
# Finished 3D outputs for id 122. 99.38856744766235 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 250. 26.636518955230713 seconds.
#
# Finished 3D outputs for id 250. 100.3513126373291 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 388. 29.54061460494995 seconds.
#
# Finished 3D outputs for id 388. 103.8063850402832 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 126. 27.54176616668701 seconds.
#
# Finished 3D outputs for id 126. 103.81956267356873 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 102. 30.43892478942871 seconds.
#
# Finished 3D outputs for id 102. 107.72019505500793 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 96. 27.004772186279297 seconds.
#
# Finished 3D outputs for id 96. 103.45464587211609 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 326. 30.029321670532227 seconds.
#
# Finished 3D outputs for id 326. 105.26816725730896 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 323. 31.424839735031128 seconds.
#
# Finished 3D outputs for id 323. 105.33021664619446 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 13. 10.76849913597107 seconds.
#
# Finished 3D outputs for id 13. 41.86824440956116 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 385. 27.466774225234985 seconds.
#
# Finished 3D outputs for id 385. 95.7101559638977 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 279. 21.924941778182983 seconds.
#
# Finished 3D outputs for id 279. 79.64402389526367 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 415. 31.005473136901855 seconds.
#
# Finished 3D outputs for id 415. 105.1584906578064 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 101. 26.68685221672058 seconds.
#
# Finished 3D outputs for id 101. 100.91674065589905 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 64. 29.546552181243896 seconds.
#
# Finished 3D outputs for id 64. 105.23786401748657 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 124. 30.131370782852173 seconds.
#
# Finished 3D outputs for id 124. 104.40101456642151 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 94. 33.35348725318909 seconds.
#
# Finished 3D outputs for id 94. 112.82530069351196 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 208. 29.06235694885254 seconds.
#
# Finished 3D outputs for id 208. 103.67520070075989 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 103. 30.80501651763916 seconds.
#
# Finished 3D outputs for id 103. 107.5925407409668 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 359. 31.46318483352661 seconds.
#
# Finished 3D outputs for id 359. 106.27142691612244 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 129. 30.197049856185913 seconds.
#
# Finished 3D outputs for id 129. 106.92954754829407 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 181. 27.648087978363037 seconds.
#
# Finished 3D outputs for id 181. 102.07612943649292 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 393. 8.389968156814575 seconds.
#
# Finished 3D outputs for id 393. 32.41952323913574 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 266. 26.20854616165161 seconds.
#
# Finished 3D outputs for id 266. 93.02762913703918 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 324. 27.889789581298828 seconds.
#
# Finished 3D outputs for id 324. 96.38146495819092 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 123. 29.503938913345337 seconds.
#
# Finished 3D outputs for id 123. 101.43055176734924 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 447. 23.830644369125366 seconds.
#
# Finished 3D outputs for id 447. 85.78272676467896 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 248. 31.842459201812744 seconds.
#
# Finished 3D outputs for id 248. 102.83367037773132 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 271. 28.26470971107483 seconds.
#
# Finished 3D outputs for id 271. 101.84408211708069 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 212. 31.376469373703003 seconds.
#
# Finished 3D outputs for id 212. 105.40070915222168 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 241. 28.202603340148926 seconds.
#
# Finished 3D outputs for id 241. 101.15772414207458 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 42. 31.333049058914185 seconds.
#
# Finished 3D outputs for id 42. 104.72365546226501 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 34. 3.202404022216797 seconds.
#
# Finished 3D outputs for id 34. 19.344785690307617 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 214. 23.99910831451416 seconds.
#
# Finished 3D outputs for id 214. 84.40063834190369 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 351. 2.791501522064209 seconds.
#
# Finished 3D outputs for id 351. 17.9170823097229 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 382. 20.014390468597412 seconds.
#
# Finished 3D outputs for id 382. 87.09896922111511 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 331. 33.122456550598145 seconds.
#
# Finished 3D outputs for id 331. 112.41626739501953 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 38. 30.63956117630005 seconds.
#
# Finished 3D outputs for id 38. 106.49328088760376 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 7. 4.6325483322143555 seconds.
#
# Finished 3D outputs for id 7. 23.501270055770874 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 191. 26.237828493118286 seconds.
#
# Finished 3D outputs for id 191. 91.6881115436554 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 157. 29.08122682571411 seconds.
#
# Finished 3D outputs for id 157. 97.39221668243408 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 278. 22.746503114700317 seconds.
#
# Finished 3D outputs for id 278. 82.97694444656372 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 9. 19.183321475982666 seconds.
#
# Finished 3D outputs for id 9. 70.24836230278015 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 275. 29.810763359069824 seconds.
#
# Finished 3D outputs for id 275. 97.14497184753418 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# ...
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 127. 28.44615912437439 seconds.
#
# Finished 3D outputs for id 127. 105.12781572341919 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 221. 27.223331928253174 seconds.
#
# Finished 3D outputs for id 221. 104.71008563041687 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 37. 29.911059856414795 seconds.
#
# Finished 3D outputs for id 37. 107.94154739379883 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 330. 30.617337465286255 seconds.
#
# Finished 3D outputs for id 330. 110.10672426223755 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 97. 30.850033044815063 seconds.
#
# Finished 3D outputs for id 97. 109.92715001106262 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 163. 21.358834266662598 seconds.
#
# Finished 3D outputs for id 163. 78.92327618598938 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 120. 30.21263813972473 seconds.
#
# Finished 3D outputs for id 120. 108.7371780872345 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 8. 13.103372812271118 seconds.
#
# Finished 3D outputs for id 8. 52.09895730018616 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 12. 17.954351663589478 seconds.
#
# Finished 3D outputs for id 12. 68.77077531814575 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 161. 33.08339238166809 seconds.
#
# Finished 3D outputs for id 161. 106.75412058830261 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 420. 27.481735944747925 seconds.
#
# Finished 3D outputs for id 420. 108.13431143760681 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 189. 31.66167378425598 seconds.
#
# Finished 3D outputs for id 189. 108.48149371147156 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 190. 32.19414210319519 seconds.
#
# Finished 3D outputs for id 190. 112.19722557067871 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 239. 31.649090051651 seconds.
#
# Finished 3D outputs for id 239. 105.07577514648438 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 303. 28.682687759399414 seconds.
#
# Finished 3D outputs for id 303. 108.72926640510559 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 155. 33.29969930648804 seconds.
#
# Finished 3D outputs for id 155. 109.51092553138733 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 65. 31.973974227905273 seconds.
#
# Finished 3D outputs for id 65. 111.51069927215576 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 154. 30.578234910964966 seconds.
#
# Finished 3D outputs for id 154. 106.93497204780579 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 360. 27.863332509994507 seconds.
#
# Finished 3D outputs for id 360. 106.62504506111145 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 238. 30.382241010665894 seconds.
#
# Finished 3D outputs for id 238. 105.3486328125 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 236. 29.916889667510986 seconds.
#
# Finished 3D outputs for id 236. 107.27097725868225 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 67. 29.95661234855652 seconds.
#
# Finished 3D outputs for id 67. 105.23607516288757 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 273. 29.914873123168945 seconds.
#
# Finished 3D outputs for id 273. 104.46786212921143 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 276. 27.133174419403076 seconds.
#
# Finished 3D outputs for id 276. 90.15177369117737 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 73. 25.658437967300415 seconds.
#
# Finished 3D outputs for id 73. 99.58985209465027 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 104. 17.19921875 seconds.
#
# Finished 3D outputs for id 104. 64.55115342140198 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 72. 27.526771783828735 seconds.
#
# Finished 3D outputs for id 72. 96.59699058532715 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 44. 12.871124982833862 seconds.
#
# Finished 3D outputs for id 44. 43.30422258377075 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 134. 6.328492879867554 seconds.
#
# Finished 3D outputs for id 134. 32.18601417541504 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 177. 26.874325037002563 seconds.
#
# Finished 3D outputs for id 177. 88.41833138465881 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 356. 27.481369733810425 seconds.
#
# Finished 3D outputs for id 356. 94.06565046310425 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 450. 8.261135816574097 seconds.
#
# Finished 3D outputs for id 450. 32.867199659347534 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 213. 25.317010164260864 seconds.
#
# Finished 3D outputs for id 213. 93.01160860061646 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 206. 27.800097227096558 seconds.
#
# Finished 3D outputs for id 206. 93.93301510810852 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 11. 20.31042766571045 seconds.
#
# Finished 3D outputs for id 11. 74.77393889427185 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 357. 27.847444772720337 seconds.
#
# Finished 3D outputs for id 357. 95.44155859947205 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 414. 30.101686000823975 seconds.
#
# Finished 3D outputs for id 414. 106.10639595985413 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 298. 31.011072397232056 seconds.
#
# Finished 3D outputs for id 298. 101.54727149009705 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 41. 28.08341097831726 seconds.
#
# Finished 3D outputs for id 41. 101.79315423965454 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 302. 28.287237644195557 seconds.
#
# Finished 3D outputs for id 302. 101.37395334243774 seconds.
#
# 0th done
# 25th done
# 50th done
# 75th done
# 98th done
# 100th done
# Mean done
# Std done
# vegtypeGGST done
# vegtypeGGW done
# nlayers done
# gapsize done
# maxpeakh done
# ptoh done
# cscore done
# FHD done
# VDR done
# meanpeakh done
# stdpeakh done
# cvpeakh done
# VDRpeak done
# herbh done
# Finished 2D outputs for id 449. 20.35102653503418 seconds.
#
# Finished 3D outputs for id 449. 72.7667019367218 seconds.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_159980/1878217590.py in <cell line: 302>()
#     300 modelmetric_df = pd.DataFrame(modelmetric_dict)
#     301 shpdf_out = shpdf.merge(modelmetric_df, on=featureIDcol)
# --> 302 shpdf_out.to_file(f'{outdir_raster}/ModelMetrics.shp')
#     303
#     304 print(f'\tSaved metric shapefile: {outdir_raster}/ModelMetrics.shp \n')
#
# NameError: name 'outdir_raster' is not defined

# %%
shpdf_out.to_file(f'{outdir_rast}/ModelMetrics.shp')
# Out:
# /n/home02/pbb/.conda/envs/Halo/lib/python3.8/site-packages/geopandas/io/file.py:299: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   pd.Int64Index,
# /tmp/ipykernel_159980/3283982990.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   shpdf_out.to_file(f'{outdir_rast}/ModelMetrics.shp')

# %% [markdown]
# ### DONE - Testing Scratch Below

# %%
# # Input directory of las files that metrics were made from
# # NOTE: currently used to define the grid
# ld = Path('/n/davies_lab/Lab/LabLidarScripts/data/out/test/lasfiles_preprocessed/Nkhulu')
# make list of pickle strings to loop through
# finds cover pickle files and grabs the output string from them
# Names = [p.name.split('_0.')[0] for p in metricdir.glob('*cover*.obj')]


#     # Get current las file that corresponds to these metrics
#     lasf = f'{ld}/{s}.las'
    
#     # open the current las file for reading
#     with laspy.open(lasf) as l:

#         # Make las boundary points from header into a polygon (ul, ur, lr, ll, ul)
#         # Ploygon is a shapely.geometry object
#         lasbounds_poly = Polygon([[l.header.mins[0], l.header.maxs[1]],
#                                   [l.header.maxs[0], l.header.maxs[1]],
#                                   [l.header.maxs[0], l.header.mins[1]],
#                                   [l.header.mins[0], l.header.mins[1]],
#                                   [l.header.mins[0], l.header.maxs[1]]])

#         # Make a geodataframe from the boundaries of the las file
#         lasbounds_gdf = gpd.GeoDataFrame(geometry=[lasbounds_poly],
#                                         crs=f'EPSG:{epsg}')

# %%
# Figure showing slight offset between coords in xlist (from cover_dict) and coords made with np.arange
# fig, ax = plt.subplots()
# ax.scatter(x_mesh, y_mesh, s=2, c='b')
# ax.scatter(xlist, ylist, s=2, c='k')
# ax.axis('equal')
# ax.margins(x=-0.49, y=-0.49)

# %%
# plt.hist(np.array(vegtypeGGST)[np.array(vegtypeGGST)>0])
