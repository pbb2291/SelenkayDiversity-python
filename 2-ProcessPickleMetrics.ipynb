# %%
# Pickle processing for point clouds 
# Note - modified 2/8/23 to loop over all radii
# Also, added grass metrics (cover and height percentiles of the grass layer)

# Import Dependencies
import sys
# Note: Selenkay uses some functions not included in the LabLidar (aka Lidar-Notebooks) Functions file
# the main functions (calculate cover, percentiles, etc) are the same
sys.path.append('/n/home02/pbb/scripts/halo-metadata-server/Selenkay/bin/')
from Functions import calccover, calcPercentileHeights, heightAggMetrics, canopyLayerMetrics
from Classes import Cloud
import geopandas as gpd
import pandas as pd
import numpy as np
import concurrent.futures
from pathlib import Path
import laspy
import time
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from shapely.geometry import Polygon
from scipy.ndimage import gaussian_filter1d
from scipy.stats import gaussian_kde
from scipy.signal import find_peaks, peak_widths
from scipy.interpolate import interp1d

# makes matplotlib plots big
plt.rcParams['figure.figsize'] = [8, 6]
plt.rcParams.update({'font.size': 14})

# # # USER INPUTS

# Set a Label for this run (unique label id)
# label= 'initial'
# mango run - 2/8/23
label = 'mango'

# Radii to loop over
radii = [20, 30, 50, 80, 130]
# just for testing!
# radii = [10]

# # Set Data Dirs

# Path to directory of shapefiles (.shp) of polygon features to clip the point cloud with.
shpd = Path('/n/home02/pbb/scripts/halo-metadata-server/Selenkay/data/in/BoundaryShapefiles/SelenkaySpotPolygons_IncreasingRadius')

# Input directory of clipped las files to compute metrics with.
# NOTE: This should be the same as the 'od' directory from 1-ClipLasWithPolygons.ipynb
lasd = Path(f'/n/davies_lab/Users/pbb/SelenkayDiversity/data/out/SpotPolys_Fibonacci_ClippedLas/')
          
# output directory for metric output files (will be organized in with subfolders labelled as 10m, 20m, etc.)
metricd = Path(f'/n/davies_lab/Users/pbb/SelenkayDiversity/data/out/Metrics/{label}/')

# output directory for complexity figures
figd = Path(f'/n/home02/pbb/scripts/halo-metadata-server/Selenkay/figs/{label}')
if not figd.exists():
    figd.mkdir()

# # Shapefile parameters

# EPSG code of the shapefile and the las files, as a string
# Note: Shapefiles and las files must have the same EPSG code (same CRS)
# Kruger is 32736 (WGS84 UTM 36S)
# Mpala is 32637 (WGS84 UTM 37N)
# Selenkay is 32737 (WGS84 UTM37S)
epsg='32737'

# feature id column - name of attribute column in shapefile which defines each polygon feature with a unique ID
featureIDcol = 'Spot'

# # Voxel Parameters

# Max height of voxel stacks 
# NOTE: Set this to be just above max height of your trees in meters.
stackheight=15

# Horizontal Res of Grid (XY pixel size)
xysize=0.5

# Vertical step size for metrics
# NOTE: This defines the vertical bin size in meters (how "thick" each voxel is).
# initial 
# verticalres = 0.5
# mango
verticalres = 0.25

# Ground threshold (i.e. below this height treat points as ground) in meters
groundthreshold = 0.05

# height col
heightcol = 'HeightAboveGround'

# # Complexity Metric Parameters

# Set method for calculation of peaks/layers (options = 'kde' or 'gauss1d')
method = 'gauss1d'

# Set smoothing sigma if using 'gauss1d"
# Initial run
# sigma = 1.5
# mango 
sigma=1.0

# set relative height for top of herb layer calc in canopyLayerMetrics
# initial run
# rh = 0.9
# mango
rh = 1.0

# # # END USER INPUTS

# %%
# Create lists of inputs and outputs to loop over
shpfs = []
lds = []
mds = []

for r in radii:
    shpfs.append(Path(f'{shpd}/SelenkaySpotPolygons_{r}mRadius.shp'))
    lds.append(Path(f'{lasd}/{r}mRadius/'))

    md = Path(f'{metricd}/{r}mRadius/')
    
    # mkdir metric dir if it doesn't exist yet
    if not md.exists():
        md.mkdir()
    
    mds.append(md)
    
# lds, mds

# %% [markdown]
# ### Make height bins for binning points

# %%
# Calc Cover for height bins
nbins = ((stackheight - 0) / verticalres) + 1
heightbins = np.linspace(0, stackheight, int(nbins))

# IMPORTANT: Using groundthres, you may want to account for errors in relative accuracy
# EX: IF the rel. accuracy of ground is about 0.06 m (6 cm) between flightlines,
# the lowest height bin could be set to 0.06 (instead of 0) to account for this.
# so any hit below 0.06 m counts as ground.
# NOTE: If you want to use everything, just set groundthres to 0
if groundthreshold > 0:
    # insert the groundthres into the array (right above 0)
    heightbins = np.insert(heightbins, 1, groundthreshold)
if groundthreshold < 0:
    # insert the groundthres into the array (right below 0)
    heightbins = np.insert(heightbins, 0, groundthreshold)

# %%
# Wrapper function for using parallel processing and calccover function 
# Notice that is calls lc as the first argument
# need to write it this way in order to use concurrent futures parallel processing below
def calccover_parallel(index, heightcol='HeightAboveGround'):

    # make a True/False array 
    # for all points within the current grid cell
    idx_bool = lc.grid_dict['idx_points'] == lc.grid_dict['idx_cells'][index]
    
    # Subset Points
    p = lc.las.points[idx_bool]

    # Get height array
    # Note: this is slightly different from the "heights" output below
    h = p[heightcol]
    
    # Remove high noise points above the canopy
    h = h[h<=stackheight]
    
    try:
        
        # Compute complexity metrics
        complexity = canopyLayerMetrics(h=h,
                                        hbins=heightbins,
                                        method=method,
                                        smoothsigma=sigma,
                                        rel_height=rh,
                                        groundthreshold=groundthreshold)
    except Exception as e:

        print(f"Complexity Calc. - {e.__class__} for {lc.lasf}: \n")
        print(f"\t{e}\n") 

    try:

        # Calculate Cover
        cover = calccover(points=p,
                          step=verticalres,
                          groundthres=groundthreshold,
                          heightcol=heightcol,
                          hmax=stackheight)
        
    except Exception as e:

        print(f"Cover Calc. - {e.__class__} for {lc.lasf}: \n")
        print(f"\t{e}\n")

    try: 
        
        # Calculate height statistics, and return an array of the point heights
        perc, heights = calcPercentileHeights(points=p,
                                              groundthres=groundthreshold,
                                              returnHeights=True,
                                              heightcol=heightcol,
                                              hmax=stackheight)
    except Exception as e:

        print(f"Percentile Calc. - {e.__class__} for {lc.lasf}: \n")
        print(f"\t{e}\n")
        
        
    # ADDED 2/8/23 - based on grass biomass work
    # Subset points to ONLY those in the grass layer
    # (where the herbaceous height in the complexity metric is used to identify the grass layer)
    grasspoints = p[p[heightcol] <= complexity['herbh']]
    
    try:
        
            grasscover = calccover(points=grasspoints,
                                   step=verticalres,
                                   groundthres=groundthreshold,
                                   heightcol=heightcol,
                                   hmax=stackheight)

            grassperc, grassheights = calcPercentileHeights(points=grasspoints,
                                                            groundthres=groundthreshold,
                                                            returnHeights=True,
                                                            heightcol=heightcol,
                                                            hmax=stackheight)
            
    except Exception as e:

        print(f"Grass Cover & Percentiles Calc. - {e.__class__} for {lc.lasf}: \n")
        print(f"\t{e}\n")
        
    # Return cover dict, percentile dict, height array, and complexity metrics
    return cover, perc, heights, complexity, grasscover, grassperc

# %%
# lds, mds, shpfs

# %%
# Looping through 
for shpf, ld, od_metrics, radius in zip(shpfs, lds, mds, radii):
    
    # make a list of input las files
    lasinputs = [str(l) for l in ld.glob('*.las')]
    
    for lasf in lasinputs:

    # For testing - only run 3a
    # for lasf in ['/n/davies_lab/Users/pbb/SelenkayDiversity/data/out/SpotPolys_Fibonacci_ClippedLas/30mRadius/Spot_3a.las']:

        ### STEP 1: Load in Cloud 
        startproj = time.time()

        # Make a las cloud class, and grid it
        lc = Cloud(lasf=lasf,
                   gridsize=xysize,
                   vsize=verticalres,
                   heightcol=heightcol,
                   maxh=stackheight)

        # get project string for saving below
        projstr = Path(lasf).name.split('.')[0].split('_')[-1]

        end = time.time()

        print(f'Loaded {projstr} cloud, time elapsed: {end - startproj}\n')

        ### STEP 2: Make the grid
        start = time.time()

        lc.makegrid()

        end = time.time()

        print(f'\tGrid created, time elapsed: {end - start}\n')

        ### STEP 2: Compute Cover, FHP, and Percentiles Metrics Over the Cloud's Grid
        start = time.time()

        # initialize dictionaries for output 
        lc.cover_dict = {}
        lc.perc_dict = {}
        lc.height_dict = {}
        lc.complexity_dict = {}
        lc.cover_dict_grass = {}
        lc.perc_dict_grass = {}

        # set the cell indices to loop over in parallel
        indices = lc.grid_dict['idx_cells']

    #     index for testing with 5D
    #     gives trouble because it has a noise height value way above the canopy
    #     # indices = [97165]

    #     # Without parallel processsing
    #     # Takes a long time, but useful for testing
    #     for i, x, y in zip(indices,
    #                        lc.grid_dict['x_cells'],
    #                        lc.grid_dict['y_cells']):

    #         cover, perc, heights, complexity = calccover_parallel(i)

    #         # Stick the cover, perc, and heights inside the metrics dictionary
    #         # with x and y location as tuple keys
    #         lc.cover_dict[(x, y)] = cover
    #         lc.perc_dict[(x, y)] = perc
    #         lc.height_dict[(x, y)] = np.round(heights, decimals=3)
    #         lc.complexity_dict[(x, y)] = complexity

        ## Use concurrent futures to compute cover over each cell in parallel
        with concurrent.futures.ProcessPoolExecutor(max_workers=None) as executor:
            for cphccp, x, y in zip(executor.map(calccover_parallel, indices),
                                     lc.grid_dict['x_cells'],
                                     lc.grid_dict['y_cells']):

                try:

                    # Stick the cover, perc, and heights inside the metrics dictionary
                    # with x and y location as tuple keys
                    lc.cover_dict[(x, y)] = cphccp[0]
                    lc.perc_dict[(x, y)] = cphccp[1]
                    lc.height_dict[(x, y)] = np.round(cphccp[2], decimals=3)
                    lc.complexity_dict[(x, y)] = cphccp[3]
                    lc.cover_dict_grass[(x, y)] = cphccp[4]
                    lc.perc_dict_grass[(x, y)] = cphccp[5]

                except Exception as e:

                    print(f"Saving metrics error - {e.__class__} for {lc.lasf} on pixel ({x}, {y}): \n")
                    print(f"\t{e}\n") 

        end = time.time()

        print(f'\tMetrics computed, time elapsed: {end - start}\n')


        ### STEP 3: SAVE GRID METRICS

        # Save outputs as pickles
        # "Can't open a pickle you don't know" - there can be malicious pickles, be wary.
        with open(f'{od_metrics}/{projstr}_{xysize}mgrid_covermetrics.obj', 'wb') as of:
            pickle.dump(lc.cover_dict, of, protocol=pickle.HIGHEST_PROTOCOL)

        with open(f'{od_metrics}/{projstr}_{xysize}mgrid_percmetrics.obj', 'wb') as of:
            pickle.dump(lc.perc_dict, of, protocol=pickle.HIGHEST_PROTOCOL)

        with open(f'{od_metrics}/{projstr}_{xysize}mgrid_heights.obj', 'wb') as of:
            pickle.dump(lc.height_dict, of, protocol=pickle.HIGHEST_PROTOCOL)

        with open(f'{od_metrics}/{projstr}_{xysize}mgrid_complexitymetrics.obj', 'wb') as of:
            pickle.dump(lc.complexity_dict, of, protocol=pickle.HIGHEST_PROTOCOL)

        with open(f'{od_metrics}/{projstr}_{xysize}mgrid_grasscovermetrics.obj', 'wb') as of:
            pickle.dump(lc.cover_dict_grass, of, protocol=pickle.HIGHEST_PROTOCOL)

        with open(f'{od_metrics}/{projstr}_{xysize}mgrid_grasspercmetrics.obj', 'wb') as of:
            pickle.dump(lc.perc_dict_grass, of, protocol=pickle.HIGHEST_PROTOCOL)

        # DONE
        endproj = time.time()
        projtime = endproj - startproj

        numcells = len(lc.grid_dict['idx_cells'])
        print(f'\t{lc.las.header.point_count} points gridded into {numcells} {xysize}m pixels in {projtime} seconds!\n')

        ### STEP 4: MAKE AND SAVE WHOLE PLOT METRICS

        start = time.time()

        # Get all points in the plot
        p = lc.las.points

        # Get height array
        # Note: this is slightly different from the "heights" output below
        hplot = p[heightcol]

        # Remove high noise points above the canopy
        hplot = hplot[hplot<=stackheight]

        try:

            # Calculate Cover
            cover_wholeplot = calccover(points=p,
                              step=verticalres,
                              groundthres=groundthreshold,
                              heightcol=heightcol,
                              hmax=stackheight)

        except Exception as e:

            print(f"Cover Calc. - {e.__class__} for {lc.lasf}: \n")
            print(f"\t{e}\n")

        try: 

            # Calculate height statistics, and return an array of the point heights
            perc_wholeplot, heights_wholeplot = calcPercentileHeights(points=p,
                                                  groundthres=groundthreshold,
                                                  returnHeights=True,
                                                  heightcol=heightcol,
                                                  hmax=stackheight)
        except Exception as e:

            print(f"Percentile Calc. - {e.__class__} for {lc.lasf}: \n")
            print(f"\t{e}\n")

        try:

            # Compute complexity metrics and make a plot
            complexity_wholeplot, fig, ax = canopyLayerMetrics(h=hplot,
                                                                hbins=heightbins,
                                                                method=method,
                                                                smoothsigma=0.5,
                                                                rel_height=rh,
                                                                plot=True,
                                                                groundthreshold=groundthreshold)

            # Save plot to fig directory
            ax.set_title(projstr)
            
            # make figdir ifnot ready
            if not Path(f'{figd}/{radius}mRadius').exists():
                Path(f'{figd}/{radius}mRadius').mkdir()
            
            fig.savefig(f'{figd}/{radius}mRadius/{projstr}_{radius}m_WholePlotProfile.png', dpi=300)
            
            plt.close(fig)
            
        except Exception as e:

            print(f"Complexity Calc. - {e.__class__} for {lc.lasf}: \n")
            print(f"\t{e}\n") 


        # Save
        with open(f'{od_metrics}/{projstr}_WholePlot_complexitymetrics.obj', 'wb') as of:
            pickle.dump(complexity_wholeplot, of, protocol=pickle.HIGHEST_PROTOCOL)

        with open(f'{od_metrics}/{projstr}_WholePlot_covermetrics.obj', 'wb') as of:
            pickle.dump(cover_wholeplot, of, protocol=pickle.HIGHEST_PROTOCOL)

        with open(f'{od_metrics}/{projstr}_WholePlot_percmetrics.obj', 'wb') as of:
            pickle.dump(perc_wholeplot, of, protocol=pickle.HIGHEST_PROTOCOL)

        end = time.time()
        endproj = time.time()

        print(f'\tWhole plot metrics in {end - start} s.\n')

        print(f'\t\tDone with processing {projstr}. Totaltime: {np.round(endproj - startproj, decimals=2)}\n')
# Out:
# Loaded 3C cloud, time elapsed: 0.06317329406738281
#
# 	Grid created, time elapsed: 0.2433934211730957
#
# 	Metrics computed, time elapsed: 4.492738723754883
#
# 	251107 points gridded into 5149 0.5m pixels in 5.830615997314453 seconds!
#
# 	Whole plot metrics in 17.18886399269104 s.
#
# 		Done with processing 3C. Totaltime: 23.02
#
# Loaded 5C cloud, time elapsed: 0.20218729972839355
#
# 	Grid created, time elapsed: 0.22739076614379883
#
# 	Metrics computed, time elapsed: 4.461066246032715
#
# 	242995 points gridded into 5143 0.5m pixels in 5.805747747421265 seconds!
#
# 	Whole plot metrics in 17.85883355140686 s.
#
# 		Done with processing 5C. Totaltime: 23.66
#
# Loaded 6B cloud, time elapsed: 0.13179469108581543
#
# 	Grid created, time elapsed: 0.24394536018371582
#
# 	Metrics computed, time elapsed: 4.728991508483887
#
# 	267980 points gridded into 5144 0.5m pixels in 6.040055990219116 seconds!
#
# 	Whole plot metrics in 19.970760345458984 s.
#
# 		Done with processing 6B. Totaltime: 26.01
#
# Loaded 8B cloud, time elapsed: 0.125748872756958
#
# 	Grid created, time elapsed: 0.24121809005737305
#
# 	Metrics computed, time elapsed: 3.8223495483398438
#
# 	266514 points gridded into 5147 0.5m pixels in 5.038362503051758 seconds!
#
# 	Whole plot metrics in 11.650937795639038 s.
#
# 		Done with processing 8B. Totaltime: 16.69
#
# Loaded 4A cloud, time elapsed: 0.1046147346496582
#
# 	Grid created, time elapsed: 0.22381830215454102
#
# 	Metrics computed, time elapsed: 4.610522985458374
#
# 	247599 points gridded into 5149 0.5m pixels in 5.915663003921509 seconds!
#
# 	Whole plot metrics in 18.05315113067627 s.
#
# 		Done with processing 4A. Totaltime: 23.97
#
# Loaded 6E cloud, time elapsed: 0.11495113372802734
#
# 	Grid created, time elapsed: 0.25808048248291016
#
# 	Metrics computed, time elapsed: 5.291077136993408
#
# 	281425 points gridded into 5147 0.5m pixels in 6.596966743469238 seconds!
#
# 	Whole plot metrics in 23.86748766899109 s.
#
# 		Done with processing 6E. Totaltime: 30.46
#
# Loaded 4D cloud, time elapsed: 0.16804718971252441
#
# 	Grid created, time elapsed: 0.21159839630126953
#
# 	Metrics computed, time elapsed: 4.454823017120361
#
# 	248670 points gridded into 5149 0.5m pixels in 5.76446533203125 seconds!
#
# 	Whole plot metrics in 14.453577518463135 s.
#
# 		Done with processing 4D. Totaltime: 20.22
#
# Loaded 3a cloud, time elapsed: 0.11612391471862793
#
# 	Grid created, time elapsed: 0.3232991695404053
#
# 	Metrics computed, time elapsed: 5.4983744621276855
#
# 	342594 points gridded into 5151 0.5m pixels in 6.908604145050049 seconds!
#
# 	Whole plot metrics in 25.886087894439697 s.
#
# 		Done with processing 3a. Totaltime: 32.79
#
# Loaded 5D cloud, time elapsed: 0.1311349868774414
#
# 	Grid created, time elapsed: 0.2523977756500244
#
# 	Metrics computed, time elapsed: 4.435957193374634
#
# 	274012 points gridded into 5144 0.5m pixels in 5.773478984832764 seconds!
#
# 	Whole plot metrics in 18.903534412384033 s.
#
# 		Done with processing 5D. Totaltime: 24.68
#
# Loaded 6A cloud, time elapsed: 0.11874055862426758
#
# 	Grid created, time elapsed: 0.2873349189758301
#
# 	Metrics computed, time elapsed: 5.240435600280762
#
# 	308124 points gridded into 5156 0.5m pixels in 6.6239705085754395 seconds!
#
# 	Whole plot metrics in 22.609136819839478 s.
#
# 		Done with processing 6A. Totaltime: 29.23
#
# Loaded 10C cloud, time elapsed: 0.13570308685302734
#
# 	Grid created, time elapsed: 0.2654597759246826
#
# 	Metrics computed, time elapsed: 4.772310018539429
#
# 	289233 points gridded into 5146 0.5m pixels in 6.033438682556152 seconds!
#
# 	Whole plot metrics in 18.598817110061646 s.
#
# 		Done with processing 10C. Totaltime: 24.63
#
# Loaded 6D cloud, time elapsed: 0.2383427619934082
#
# 	Grid created, time elapsed: 0.2867755889892578
#
# 	Metrics computed, time elapsed: 5.27377724647522
#
# 	305622 points gridded into 5150 0.5m pixels in 6.794794797897339 seconds!
#
# 	Whole plot metrics in 21.70045018196106 s.
#
# 		Done with processing 6D. Totaltime: 28.5
#
# Loaded 5A cloud, time elapsed: 0.13407564163208008
#
# 	Grid created, time elapsed: 0.22367525100708008
#
# 	Metrics computed, time elapsed: 4.891100883483887
#
# 	242303 points gridded into 5141 0.5m pixels in 6.202240228652954 seconds!
#
# 	Whole plot metrics in 18.26142406463623 s.
#
# 		Done with processing 5A. Totaltime: 24.46
#
# Loaded 1C cloud, time elapsed: 0.1356658935546875
#
# 	Grid created, time elapsed: 0.21524524688720703
#
# 	Metrics computed, time elapsed: 4.212488651275635
#
# 	246576 points gridded into 5153 0.5m pixels in 5.508554935455322 seconds!
#
# 	Whole plot metrics in 12.508065223693848 s.
#
# 		Done with processing 1C. Totaltime: 18.02
#
# Loaded 10B cloud, time elapsed: 0.10012292861938477
#
# 	Grid created, time elapsed: 0.2452385425567627
#
# 	Metrics computed, time elapsed: 4.773249864578247
#
# 	265470 points gridded into 5157 0.5m pixels in 5.946680068969727 seconds!
#
# 	Whole plot metrics in 16.434698581695557 s.
#
# 		Done with processing 10B. Totaltime: 22.38
#
# Loaded 4C cloud, time elapsed: 0.11327433586120605
#
# 	Grid created, time elapsed: 0.22409892082214355
#
# 	Metrics computed, time elapsed: 4.796032190322876
#
# 	244764 points gridded into 5143 0.5m pixels in 6.09289288520813 seconds!
#
# 	Whole plot metrics in 16.80772376060486 s.
#
# 		Done with processing 4C. Totaltime: 22.9
#
# Loaded 4B cloud, time elapsed: 0.1449880599975586
#
# 	Grid created, time elapsed: 0.23825645446777344
#
# 	Metrics computed, time elapsed: 5.203219652175903
#
# 	258775 points gridded into 5149 0.5m pixels in 6.471141576766968 seconds!
#
# 	Whole plot metrics in 19.637253046035767 s.
#
# 		Done with processing 4B. Totaltime: 26.11
#
# Loaded 3D cloud, time elapsed: 0.1881554126739502
#
# 	Grid created, time elapsed: 0.2507174015045166
#
# 	Metrics computed, time elapsed: 5.599448204040527
#
# 	265900 points gridded into 5149 0.5m pixels in 7.041333436965942 seconds!
#
# 	Whole plot metrics in 22.119848489761353 s.
#
# 		Done with processing 3D. Totaltime: 29.16
#
# Loaded 10D cloud, time elapsed: 0.16404318809509277
#
# 	Grid created, time elapsed: 0.25223708152770996
#
# 	Metrics computed, time elapsed: 4.831441640853882
#
# 	274268 points gridded into 5147 0.5m pixels in 6.1949639320373535 seconds!
#
# 	Whole plot metrics in 16.570654153823853 s.
#
# 		Done with processing 10D. Totaltime: 22.77
#
# Loaded 5E cloud, time elapsed: 0.1512916088104248
#
# 	Grid created, time elapsed: 0.2388458251953125
#
# 	Metrics computed, time elapsed: 5.074281692504883
#
# 	256653 points gridded into 5149 0.5m pixels in 6.451009273529053 seconds!
#
# 	Whole plot metrics in 18.513153076171875 s.
#
# 		Done with processing 5E. Totaltime: 24.96
#
# Loaded 7B cloud, time elapsed: 0.12879323959350586
#
# 	Grid created, time elapsed: 0.23976945877075195
#
# 	Metrics computed, time elapsed: 3.723069429397583
#
# 	264920 points gridded into 5153 0.5m pixels in 5.034463882446289 seconds!
#
# 	Whole plot metrics in 11.50778603553772 s.
#
# 		Done with processing 7B. Totaltime: 16.54
#
# Loaded 8A cloud, time elapsed: 0.1235649585723877
#
# 	Grid created, time elapsed: 0.22612810134887695
#
# 	Metrics computed, time elapsed: 3.5291168689727783
#
# 	249995 points gridded into 5153 0.5m pixels in 4.793366193771362 seconds!
#
# 	Whole plot metrics in 8.011939764022827 s.
#
# 		Done with processing 8A. Totaltime: 12.81
#
# Loaded 7D cloud, time elapsed: 0.18436622619628906
#
# 	Grid created, time elapsed: 0.304776668548584
#
# 	Metrics computed, time elapsed: 4.5358099937438965
#
# 	316945 points gridded into 5147 0.5m pixels in 6.006977558135986 seconds!
#
# 	Whole plot metrics in 18.64710235595703 s.
#
# 		Done with processing 7D. Totaltime: 24.65
#
# Loaded 2A cloud, time elapsed: 0.15646982192993164
#
# 	Grid created, time elapsed: 0.21040940284729004
#
# 	Metrics computed, time elapsed: 4.079004764556885
#
# 	244491 points gridded into 5155 0.5m pixels in 5.384052991867065 seconds!
#
# 	Whole plot metrics in 10.956411838531494 s.
#
# 		Done with processing 2A. Totaltime: 16.34
#
# Loaded 10E cloud, time elapsed: 0.15104198455810547
#
# 	Grid created, time elapsed: 0.23431062698364258
#
# 	Metrics computed, time elapsed: 4.386319398880005
#
# 	255575 points gridded into 5147 0.5m pixels in 5.595254421234131 seconds!
#
# 	Whole plot metrics in 14.568967342376709 s.
#
# 		Done with processing 10E. Totaltime: 20.16
#
# Loaded 9B cloud, time elapsed: 0.11683893203735352
#
# 	Grid created, time elapsed: 0.24032855033874512
#
# 	Metrics computed, time elapsed: 4.771523475646973
#
# 	263704 points gridded into 5154 0.5m pixels in 5.965830087661743 seconds!
#
# 	Whole plot metrics in 16.230648517608643 s.
#
# 		Done with processing 9B. Totaltime: 22.2
#
# Loaded 1E cloud, time elapsed: 0.12379765510559082
#
# 	Grid created, time elapsed: 0.2225508689880371
#
# 	Metrics computed, time elapsed: 4.272693872451782
#
# 	255254 points gridded into 5149 0.5m pixels in 5.579104423522949 seconds!
#
# 	Whole plot metrics in 12.514477252960205 s.
#
# 		Done with processing 1E. Totaltime: 18.09
#
# Loaded 9D cloud, time elapsed: 0.1672830581665039
#
# 	Grid created, time elapsed: 0.2995162010192871
#
# 	Metrics computed, time elapsed: 4.774346351623535
#
# 	316187 points gridded into 5153 0.5m pixels in 6.289136171340942 seconds!
#
# 	Whole plot metrics in 19.700748443603516 s.
#
# 		Done with processing 9D. Totaltime: 25.99
#
# Loaded 9E cloud, time elapsed: 0.10963821411132812
#
# 	Grid created, time elapsed: 0.2519218921661377
#
# 	Metrics computed, time elapsed: 4.683863162994385
#
# 	257241 points gridded into 5148 0.5m pixels in 6.057005405426025 seconds!
#
# 	Whole plot metrics in 16.643082857131958 s.
#
# 		Done with processing 9E. Totaltime: 22.7
#
# Loaded 7A cloud, time elapsed: 0.14080309867858887
#
# 	Grid created, time elapsed: 0.3238518238067627
#
# 	Metrics computed, time elapsed: 4.5400683879852295
#
# 	345576 points gridded into 5149 0.5m pixels in 6.043720483779907 seconds!
#
# 	Whole plot metrics in 20.09177803993225 s.
#
# 		Done with processing 7A. Totaltime: 26.14
#
# Loaded 9C cloud, time elapsed: 0.16734027862548828
#
# 	Grid created, time elapsed: 0.2525758743286133
#
# 	Metrics computed, time elapsed: 4.8085761070251465
#
# 	269204 points gridded into 5149 0.5m pixels in 6.246258735656738 seconds!
#
# 	Whole plot metrics in 17.57277798652649 s.
#
# 		Done with processing 9C. Totaltime: 23.82
#
# Loaded 1A cloud, time elapsed: 0.18523335456848145
#
# 	Grid created, time elapsed: 0.2476639747619629
#
# 	Metrics computed, time elapsed: 5.065645217895508
#
# 	277575 points gridded into 5146 0.5m pixels in 6.546865940093994 seconds!
#
# 	Whole plot metrics in 18.958218097686768 s.
#
# 		Done with processing 1A. Totaltime: 25.51
#
# Loaded 2E cloud, time elapsed: 0.15122079849243164
#
# 	Grid created, time elapsed: 0.21777963638305664
#
# 	Metrics computed, time elapsed: 3.025489568710327
#
# 	243981 points gridded into 5146 0.5m pixels in 4.314758777618408 seconds!
#
# 	Whole plot metrics in 3.703000545501709 s.
#
# 		Done with processing 2E. Totaltime: 8.02
#
# Loaded 9A cloud, time elapsed: 0.10329914093017578
#
# 	Grid created, time elapsed: 0.23990368843078613
#
# 	Metrics computed, time elapsed: 4.664050579071045
#
# 	260522 points gridded into 5154 0.5m pixels in 6.011070966720581 seconds!
#
# 	Whole plot metrics in 16.328036546707153 s.
#
# 		Done with processing 9A. Totaltime: 22.34
#
# Loaded 4E cloud, time elapsed: 0.12923550605773926
#
# 	Grid created, time elapsed: 0.2543191909790039
#
# 	Metrics computed, time elapsed: 5.109193801879883
#
# 	275858 points gridded into 5155 0.5m pixels in 6.539130449295044 seconds!
#
# 	Whole plot metrics in 17.838671445846558 s.
#
# 		Done with processing 4E. Totaltime: 24.38
#
# Loaded 3B cloud, time elapsed: 0.14815855026245117
#
# 	Grid created, time elapsed: 0.26595258712768555
#
# 	Metrics computed, time elapsed: 5.182786703109741
#
# 	285305 points gridded into 5149 0.5m pixels in 6.652669906616211 seconds!
#
# 	Whole plot metrics in 18.234564781188965 s.
#
# 		Done with processing 3B. Totaltime: 24.89
#
# Loaded 3E cloud, time elapsed: 0.15612554550170898
#
# 	Grid created, time elapsed: 0.24002599716186523
#
# 	Metrics computed, time elapsed: 5.743068695068359
#
# 	264569 points gridded into 5152 0.5m pixels in 7.0720250606536865 seconds!
#
# 	Whole plot metrics in 21.616979122161865 s.
#
# 		Done with processing 3E. Totaltime: 28.69
#
# Loaded 2B cloud, time elapsed: 0.13641953468322754
#
# 	Grid created, time elapsed: 0.26422953605651855
#
# 	Metrics computed, time elapsed: 5.017426252365112
#
# 	297454 points gridded into 5150 0.5m pixels in 6.4833269119262695 seconds!
#
# 	Whole plot metrics in 18.90089201927185 s.
#
# 		Done with processing 2B. Totaltime: 25.38
#
# Loaded 7C cloud, time elapsed: 0.1169576644897461
#
# 	Grid created, time elapsed: 0.2540912628173828
#
# 	Metrics computed, time elapsed: 4.054775714874268
#
# 	275554 points gridded into 5150 0.5m pixels in 5.270092725753784 seconds!
#
# 	Whole plot metrics in 12.511526584625244 s.
#
# 		Done with processing 7C. Totaltime: 17.78
#
# Loaded 8C cloud, time elapsed: 0.14561128616333008
#
# 	Grid created, time elapsed: 0.23407602310180664
#
# 	Metrics computed, time elapsed: 4.356204986572266
#
# 	255451 points gridded into 5153 0.5m pixels in 5.573389530181885 seconds!
#
# 	Whole plot metrics in 10.850355863571167 s.
#
# 		Done with processing 8C. Totaltime: 16.42
#
# Loaded 1B cloud, time elapsed: 0.11732745170593262
#
# 	Grid created, time elapsed: 0.2380375862121582
#
# 	Metrics computed, time elapsed: 5.071075916290283
#
# 	270981 points gridded into 5151 0.5m pixels in 6.501643419265747 seconds!
#
# 	Whole plot metrics in 18.082719564437866 s.
#
# 		Done with processing 1B. Totaltime: 24.58
#
# Loaded 2C cloud, time elapsed: 0.11581158638000488
#
# 	Grid created, time elapsed: 0.23130464553833008
#
# 	Metrics computed, time elapsed: 3.5381438732147217
#
# 	255776 points gridded into 5153 0.5m pixels in 4.851084232330322 seconds!
#
# 	Whole plot metrics in 6.068261384963989 s.
#
# 		Done with processing 2C. Totaltime: 10.92
#
# Loaded 8D cloud, time elapsed: 0.13166427612304688
#
# 	Grid created, time elapsed: 0.23957562446594238
#
# 	Metrics computed, time elapsed: 4.316134929656982
#
# 	259376 points gridded into 5153 0.5m pixels in 5.579348564147949 seconds!
#
# 	Whole plot metrics in 11.461727142333984 s.
#
# 		Done with processing 8D. Totaltime: 17.04
#
# Loaded 7E cloud, time elapsed: 0.15961098670959473
#
# 	Grid created, time elapsed: 0.1804659366607666
#
# 	Metrics computed, time elapsed: 4.447058916091919
#
# 	198353 points gridded into 5146 0.5m pixels in 5.6967291831970215 seconds!
#
# 	Whole plot metrics in 10.911807775497437 s.
#
# 		Done with processing 7E. Totaltime: 16.61
#
# Loaded 10A cloud, time elapsed: 0.11631989479064941
#
# 	Grid created, time elapsed: 0.27216672897338867
#
# 	Metrics computed, time elapsed: 5.840318918228149
#
# 	295828 points gridded into 5152 0.5m pixels in 7.134686231613159 seconds!
#
# 	Whole plot metrics in 20.88206386566162 s.
#
# 		Done with processing 10A. Totaltime: 28.02
#
# Loaded 1D cloud, time elapsed: 0.11238813400268555
#
# 	Grid created, time elapsed: 0.24292826652526855
#
# 	Metrics computed, time elapsed: 5.627890110015869
#
# 	275394 points gridded into 5152 0.5m pixels in 7.0771214962005615 seconds!
#
# 	Whole plot metrics in 20.17775273323059 s.
#
# 		Done with processing 1D. Totaltime: 27.25
#
# Loaded 5B cloud, time elapsed: 0.1255626678466797
#
# 	Grid created, time elapsed: 0.2443997859954834
#
# 	Metrics computed, time elapsed: 5.533314228057861
#
# 	259678 points gridded into 5148 0.5m pixels in 6.861201763153076 seconds!
#
# 	Whole plot metrics in 20.01177740097046 s.
#
# 		Done with processing 5B. Totaltime: 26.87
#
# Loaded 8E cloud, time elapsed: 0.17878007888793945
#
# 	Grid created, time elapsed: 0.26490259170532227
#
# 	Metrics computed, time elapsed: 4.786785364151001
#
# 	289516 points gridded into 5145 0.5m pixels in 6.11125636100769 seconds!
#
# 	Whole plot metrics in 14.633931398391724 s.
#
# 		Done with processing 8E. Totaltime: 20.75
#
# Loaded 2D cloud, time elapsed: 0.1451888084411621
#
# 	Grid created, time elapsed: 0.23278212547302246
#
# 	Metrics computed, time elapsed: 4.314050197601318
#
# 	248990 points gridded into 5154 0.5m pixels in 5.605933666229248 seconds!
#
# 	Whole plot metrics in 9.501314878463745 s.
#
# 		Done with processing 2D. Totaltime: 15.11
#
# Loaded 6C cloud, time elapsed: 0.10035586357116699
#
# 	Grid created, time elapsed: 0.24227237701416016
#
# 	Metrics computed, time elapsed: 4.971906661987305
#
# 	268576 points gridded into 5148 0.5m pixels in 6.447476863861084 seconds!
#
# 	Whole plot metrics in 15.942575454711914 s.
#
# 		Done with processing 6C. Totaltime: 22.39
#
# Loaded 3C cloud, time elapsed: 0.17119646072387695
#
# 	Grid created, time elapsed: 0.5552246570587158
#
# 	Metrics computed, time elapsed: 10.749560117721558
#
# 	570665 points gridded into 11490 0.5m pixels in 13.737618446350098 seconds!
#
# 	Whole plot metrics in 39.14132308959961 s.
#
# 		Done with processing 3C. Totaltime: 52.88
#
# Loaded 5C cloud, time elapsed: 0.2574167251586914
#
# 	Grid created, time elapsed: 0.5685999393463135
#
# 	Metrics computed, time elapsed: 10.915254592895508
#
# 	586136 points gridded into 11487 0.5m pixels in 13.917459487915039 seconds!
#
# 	Whole plot metrics in 43.82878494262695 s.
#
# 		Done with processing 5C. Totaltime: 57.75
#
# Loaded 6B cloud, time elapsed: 0.2872793674468994
#
# 	Grid created, time elapsed: 0.6157422065734863
#
# 	Metrics computed, time elapsed: 11.528565645217896
#
# 	629477 points gridded into 11485 0.5m pixels in 14.911879777908325 seconds!
#
# 	Whole plot metrics in 45.67855143547058 s.
#
# 		Done with processing 6B. Totaltime: 60.59
#
# Loaded 8B cloud, time elapsed: 0.3043053150177002
#
# 	Grid created, time elapsed: 0.5742008686065674
#
# 	Metrics computed, time elapsed: 8.84078574180603
#
# 	583243 points gridded into 11484 0.5m pixels in 11.763755083084106 seconds!
#
# 	Whole plot metrics in 24.222022533416748 s.
#
# 		Done with processing 8B. Totaltime: 35.99
#
# Loaded 4A cloud, time elapsed: 0.30040812492370605
#
# 	Grid created, time elapsed: 0.5615501403808594
#
# 	Metrics computed, time elapsed: 10.965288400650024
#
# 	572898 points gridded into 11484 0.5m pixels in 14.309704303741455 seconds!
#
# 	Whole plot metrics in 42.02998971939087 s.
#
# 		Done with processing 4A. Totaltime: 56.34
#
# Loaded 6E cloud, time elapsed: 0.2992250919342041
#
# 	Grid created, time elapsed: 0.6071689128875732
#
# 	Metrics computed, time elapsed: 12.140355110168457
#
# 	609864 points gridded into 11489 0.5m pixels in 15.287090301513672 seconds!
#
# 	Whole plot metrics in 48.581862449645996 s.
#
# 		Done with processing 6E. Totaltime: 63.87
#
# Loaded 4D cloud, time elapsed: 0.2849454879760742
#
# 	Grid created, time elapsed: 0.49738001823425293
#
# 	Metrics computed, time elapsed: 9.826853275299072
#
# 	545861 points gridded into 11475 0.5m pixels in 13.051617860794067 seconds!
#
# 	Whole plot metrics in 30.641181230545044 s.
#
# 		Done with processing 4D. Totaltime: 43.69
#
# Loaded 3a cloud, time elapsed: 0.29667139053344727
#
# 	Grid created, time elapsed: 0.744680643081665
#
# 	Metrics computed, time elapsed: 12.619110107421875
#
# 	746502 points gridded into 11486 0.5m pixels in 15.974169254302979 seconds!
#
# 	Whole plot metrics in 55.28884530067444 s.
#
# 		Done with processing 3a. Totaltime: 71.26
#
# Loaded 5D cloud, time elapsed: 0.2750391960144043
#
# 	Grid created, time elapsed: 0.6233673095703125
#
# 	Metrics computed, time elapsed: 10.620942831039429
#
# 	626696 points gridded into 11485 0.5m pixels in 13.76079797744751 seconds!
#
# 	Whole plot metrics in 44.04677629470825 s.
#
# 		Done with processing 5D. Totaltime: 57.81
#
# Loaded 6A cloud, time elapsed: 0.280747652053833
#
# 	Grid created, time elapsed: 0.6408119201660156
#
# 	Metrics computed, time elapsed: 11.505694389343262
#
# 	651149 points gridded into 11488 0.5m pixels in 14.704046487808228 seconds!
#
# 	Whole plot metrics in 47.02795720100403 s.
#
# 		Done with processing 6A. Totaltime: 61.73
#
# Loaded 10C cloud, time elapsed: 0.2839512825012207
#
# 	Grid created, time elapsed: 0.6060080528259277
#
# 	Metrics computed, time elapsed: 10.80443024635315
#
# 	619415 points gridded into 11487 0.5m pixels in 13.796533823013306 seconds!
#
# 	Whole plot metrics in 39.30993294715881 s.
#
# 		Done with processing 10C. Totaltime: 53.11
#
# Loaded 6D cloud, time elapsed: 0.27068018913269043
#
# 	Grid created, time elapsed: 0.7562317848205566
#
# 	Metrics computed, time elapsed: 12.504805564880371
#
# 	745054 points gridded into 11488 0.5m pixels in 15.80346393585205 seconds!
#
# 	Whole plot metrics in 51.830135107040405 s.
#
# 		Done with processing 6D. Totaltime: 67.63
#
# Loaded 5A cloud, time elapsed: 0.38436079025268555
#
# 	Grid created, time elapsed: 0.5684912204742432
#
# 	Metrics computed, time elapsed: 10.81803035736084
#
# 	580116 points gridded into 11485 0.5m pixels in 14.318533658981323 seconds!
#
# 	Whole plot metrics in 42.595730781555176 s.
#
# 		Done with processing 5A. Totaltime: 56.91
#
# Loaded 1C cloud, time elapsed: 0.30625391006469727
#
# 	Grid created, time elapsed: 0.528606653213501
#
# 	Metrics computed, time elapsed: 9.938513994216919
#
# 	572519 points gridded into 11492 0.5m pixels in 12.997048616409302 seconds!
#
# 	Whole plot metrics in 30.714019060134888 s.
#
# 		Done with processing 1C. Totaltime: 43.71
#
# Loaded 10B cloud, time elapsed: 0.24223661422729492
#
# 	Grid created, time elapsed: 0.5881803035736084
#
# 	Metrics computed, time elapsed: 10.480010747909546
#
# 	598758 points gridded into 11488 0.5m pixels in 13.704073667526245 seconds!
#
# 	Whole plot metrics in 36.74175953865051 s.
#
# 		Done with processing 10B. Totaltime: 50.45
#
# Loaded 4C cloud, time elapsed: 0.2521529197692871
#
# 	Grid created, time elapsed: 0.5621912479400635
#
# 	Metrics computed, time elapsed: 10.943350315093994
#
# 	571485 points gridded into 11485 0.5m pixels in 13.998198986053467 seconds!
#
# 	Whole plot metrics in 39.35748767852783 s.
#
# 		Done with processing 4C. Totaltime: 53.36
#
# Loaded 4B cloud, time elapsed: 0.2717125415802002
#
# 	Grid created, time elapsed: 0.5784645080566406
#
# 	Metrics computed, time elapsed: 11.445640325546265
#
# 	579240 points gridded into 11482 0.5m pixels in 14.586632490158081 seconds!
#
# 	Whole plot metrics in 43.140249729156494 s.
#
# 		Done with processing 4B. Totaltime: 57.73
#
# Loaded 3D cloud, time elapsed: 0.25394415855407715
#
# 	Grid created, time elapsed: 0.6111462116241455
#
# 	Metrics computed, time elapsed: 12.896787166595459
#
# 	626993 points gridded into 11489 0.5m pixels in 16.02562642097473 seconds!
#
# 	Whole plot metrics in 53.3925895690918 s.
#
# 		Done with processing 3D. Totaltime: 69.42
#
# Loaded 10D cloud, time elapsed: 0.29094600677490234
#
# 	Grid created, time elapsed: 0.6023776531219482
#
# 	Metrics computed, time elapsed: 10.644508123397827
#
# 	618130 points gridded into 11486 0.5m pixels in 13.986810684204102 seconds!
#
# 	Whole plot metrics in 37.469112157821655 s.
#
# 		Done with processing 10D. Totaltime: 51.46
#
# Loaded 5E cloud, time elapsed: 0.24331355094909668
#
# 	Grid created, time elapsed: 0.5988516807556152
#
# 	Metrics computed, time elapsed: 11.091660737991333
#
# 	587502 points gridded into 11485 0.5m pixels in 13.940895318984985 seconds!
#
# 	Whole plot metrics in 40.7520387172699 s.
#
# 		Done with processing 5E. Totaltime: 54.69
#
# Loaded 7B cloud, time elapsed: 0.28295111656188965
#
# 	Grid created, time elapsed: 0.6043879985809326
#
# 	Metrics computed, time elapsed: 8.645272731781006
#
# 	623399 points gridded into 11485 0.5m pixels in 11.702958583831787 seconds!
#
# 	Whole plot metrics in 27.044952630996704 s.
#
# 		Done with processing 7B. Totaltime: 38.75
#
# Loaded 8A cloud, time elapsed: 0.2537384033203125
#
# 	Grid created, time elapsed: 0.5494215488433838
#
# 	Metrics computed, time elapsed: 7.9546144008636475
#
# 	554738 points gridded into 11495 0.5m pixels in 10.826687812805176 seconds!
#
# 	Whole plot metrics in 18.421703100204468 s.
#
# 		Done with processing 8A. Totaltime: 29.25
#
# Loaded 7D cloud, time elapsed: 0.2656593322753906
#
# 	Grid created, time elapsed: 0.6703107357025146
#
# 	Metrics computed, time elapsed: 9.99260926246643
#
# 	670371 points gridded into 11479 0.5m pixels in 12.888758420944214 seconds!
#
# 	Whole plot metrics in 38.10615420341492 s.
#
# 		Done with processing 7D. Totaltime: 50.99
#
# Loaded 2A cloud, time elapsed: 0.2675015926361084
#
# 	Grid created, time elapsed: 0.5082616806030273
#
# 	Metrics computed, time elapsed: 9.23593521118164
#
# 	549973 points gridded into 11487 0.5m pixels in 12.187827110290527 seconds!
#
# 	Whole plot metrics in 25.072227001190186 s.
#
# 		Done with processing 2A. Totaltime: 37.26
#
# Loaded 10E cloud, time elapsed: 0.2886371612548828
#
# 	Grid created, time elapsed: 0.5831441879272461
#
# 	Metrics computed, time elapsed: 9.50669240951538
#
# 	588397 points gridded into 11479 0.5m pixels in 12.485853672027588 seconds!
#
# 	Whole plot metrics in 32.85666632652283 s.
#
# 		Done with processing 10E. Totaltime: 45.34
#
# Loaded 9B cloud, time elapsed: 0.3243734836578369
#
# 	Grid created, time elapsed: 0.5856332778930664
#
# 	Metrics computed, time elapsed: 10.582879543304443
#
# 	596963 points gridded into 11482 0.5m pixels in 13.700324296951294 seconds!
#
# 	Whole plot metrics in 36.18453240394592 s.
#
# 		Done with processing 9B. Totaltime: 49.88
#
# Loaded 1E cloud, time elapsed: 0.21687984466552734
#
# 	Grid created, time elapsed: 0.5454506874084473
#
# 	Metrics computed, time elapsed: 9.366398334503174
#
# 	594436 points gridded into 11482 0.5m pixels in 12.368012428283691 seconds!
#
# 	Whole plot metrics in 28.98834991455078 s.
#
# 		Done with processing 1E. Totaltime: 41.36
#
# Loaded 9D cloud, time elapsed: 0.23024535179138184
#
# 	Grid created, time elapsed: 0.7906579971313477
#
# 	Metrics computed, time elapsed: 10.550288200378418
#
# 	765404 points gridded into 11492 0.5m pixels in 14.2053804397583 seconds!
#
# 	Whole plot metrics in 47.948838233947754 s.
#
# 		Done with processing 9D. Totaltime: 62.15
#
# Loaded 9E cloud, time elapsed: 0.23022127151489258
#
# 	Grid created, time elapsed: 0.6926236152648926
#
# 	Metrics computed, time elapsed: 10.532938480377197
#
# 	641458 points gridded into 11490 0.5m pixels in 13.77795147895813 seconds!
#
# 	Whole plot metrics in 40.83586096763611 s.
#
# 		Done with processing 9E. Totaltime: 54.61
#
# Loaded 7A cloud, time elapsed: 0.2980825901031494
#
# 	Grid created, time elapsed: 0.7905972003936768
#
# 	Metrics computed, time elapsed: 10.368809461593628
#
# 	763493 points gridded into 11490 0.5m pixels in 13.537663698196411 seconds!
#
# 	Whole plot metrics in 44.14699864387512 s.
#
# 		Done with processing 7A. Totaltime: 57.68
#
# Loaded 9C cloud, time elapsed: 0.25691652297973633
#
# 	Grid created, time elapsed: 0.6131758689880371
#
# 	Metrics computed, time elapsed: 10.845489501953125
#
# 	620935 points gridded into 11478 0.5m pixels in 13.741593837738037 seconds!
#
# 	Whole plot metrics in 40.08238768577576 s.
#
# 		Done with processing 9C. Totaltime: 53.82
#
# Loaded 1A cloud, time elapsed: 0.22132325172424316
#
# 	Grid created, time elapsed: 0.5895493030548096
#
# 	Metrics computed, time elapsed: 11.359176635742188
#
# 	624096 points gridded into 11489 0.5m pixels in 14.518683433532715 seconds!

# %% [markdown]
# ## TESTING

# %%
# # Make and Save Plot-level complexity and height metrics as well
# start = time.time()

# # Subset Points
# p = lc.las.points

# # Get height array
# # Note: this is slightly different from the "heights" output below
# h = p[heightcol]

# # Remove high noise points above the canopy
# h = h[h<=stackheight]

# # try:

# #     # Calculate Cover
# #     cover_wholeplot = calccover(points=p,
# #                       step=verticalres,
# #                       groundthres=groundthreshold,
# #                       heightcol=heightcol,
# #                       hmax=stackheight)

# # except Exception as e:

# #     print(f"Cover Calc. - {e.__class__} for {lc.lasf}: \n")
# #     print(f"\t{e}\n")

# # try: 

# #     # Calculate height statistics, and return an array of the point heights
# #     perc_wholeplot, heights_wholeplot = calcPercentileHeights(points=p,
# #                                           groundthres=groundthreshold,
# #                                           returnHeights=True,
# #                                           heightcol=heightcol,
# #                                           hmax=stackheight)
# # except Exception as e:

# #     print(f"Percentile Calc. - {e.__class__} for {lc.lasf}: \n")
# #     print(f"\t{e}\n")

# try:

#     # Compute complexity metrics
#     complexity_wholeplot, fig, ax = canopyLayerMetrics(h=h,
#                                                         hbins=heightbins,
#                                                         method='gauss1d',
#                                                         smoothsigma=0.5,
#                                                         rel_height=rh,
#                                                         plot=True)
# except Exception as e:

#     print(f"Complexity Calc. - {e.__class__} for {lc.lasf}: \n")
#     print(f"\t{e}\n") 


# end = time.time()

# print(f'Finished whole plot metrics in {end - start} s.\n')

# ax.set_title(projstr)

# fig.savefig(f'./figs/WholePlotProfiles/{radius}m/{projstr}_{radius}mRadius_WholePlotProfile.png', dpi=300)
# ax.set_ylim([-0.1, 15])

# %%
# # make a True/False array 
# # for all points within the current grid cell
# idx_bool = lc.grid_dict['idx_points'] == lc.grid_dict['idx_cells'][index]

# # Subset Points
# p = lc.las.points[idx_bool]

# # Get height array
# # Note: this is slightly different from the "heights" output below
# h = p[heightcol]

# # Remove high noise points above the canopy
# h = h[h<=stackheight]

# try: 

#     # Calculate height statistics, and return an array of the point heights
#     perc, heights = calcPercentileHeights(points=p,
#                                           groundthres=groundthreshold,
#                                           returnHeights=True,
#                                           heightcol=heightcol,
#                                           hmax=stackheight)
# except Exception as e:

#     print(f"Percentile Calc. - {e.__class__} for {lc.lasf}: \n")
#     print(f"\t{e}\n")

# try:

#     # Compute complexity metrics
#     complexity= canopyLayerMetrics(h=h,
#                                     hbins=heightbins,
#                                     method='gauss1d',
#                                     smoothsigma=sigma,
#                                     rel_height=rh,
#                                     plot=True)
    
# except Exception as e:

#     print(f"Complexity Calc. - {e.__class__} for {lc.lasf}: \n")
#     print(f"\t{e}\n")

# %%
# # make a True/False array 
# # for all points within the current grid cell
# idx_bool = lc.grid_dict['idx_points'] == lc.grid_dict['idx_cells'][index]

# # Subset Points
# p = lc.las.points[idx_bool]

# # Get height array
# # Note: this is slightly different from the "heights" output below
# h = p[heightcol]

# # Remove high noise points above the canopy
# h = h[h<=stackheight]

# try: 

#     # Calculate height statistics, and return an array of the point heights
#     perc, heights = calcPercentileHeights(points=p,
#                                           groundthres=groundthreshold,
#                                           returnHeights=True,
#                                           heightcol=heightcol,
#                                           hmax=stackheight)
# except Exception as e:

#     print(f"Percentile Calc. - {e.__class__} for {lc.lasf}: \n")
#     print(f"\t{e}\n")

# try:

#     # Compute complexity metrics
#     complexity= canopyLayerMetrics(h=h,
#                                     hbins=heightbins,
#                                     method='gauss1d',
#                                     smoothsigma=sigma,
#                                     rel_height=rh,
#                                     plot=True)
    
# except Exception as e:

#     print(f"Complexity Calc. - {e.__class__} for {lc.lasf}: \n")
#     print(f"\t{e}\n")

# %%
#     print(i, x, y)
    
#     index = i
#     # make a True/False array 
#     # for all points within the current grid cell
#     idx_bool = lc.grid_dict['idx_points'] == lc.grid_dict['idx_cells'][index]
    
#     # Subset Points
#     p = lc.las.points[idx_bool]

#     # Get height array
#     # Note: this is slightly different from the "heights" output below
#     h = p[heightcol]
    
#     # Remove high noise points above the canopy
#     h = h[h<=stackheight]
    
#         # Calculate height statistics, and return an array of the point heights
#     perc, heights = calcPercentileHeights(points=p,
#                                           groundthres=groundthreshold,
#                                           returnHeights=True,
#                                           heightcol=heightcol,
#                                           hmax=stackheight)
    
#         # Compute complexity metrics
#     complexity = canopyLayerMetrics(h=h,
#                                     hbins=heightbins,
#                                     method='kde',
#                                     rel_height=0.9)

# %%
# percdict = {}
# heightdict = {}
# complexdict = {}

# # Testing - funky error with 5D and complexity 10/25
# for lasf in ['/n/davies_lab/Users/pbb/SelenkayDiversity/data/out/SpotPolys_Fibonacci_ClippedLas/130mRadius/Spot_5D.las']:

#     ### STEP 1: Load in Cloud 
#     startproj = time.time()

#     # Make a las cloud class, and grid it
#     lc = Cloud(lasf=lasf,
#                gridsize=xysize,
#                vsize=verticalres,
#                heightcol=heightcol,
#                maxh=stackheight)
    
#     lasf = Path(lasf)
#     # get project string for saving below
#     projstr = lasf.name.split('.')[0].split('_')[-1]

#     end = time.time()
    
#     print(f'Loaded {projstr} cloud, time elapsed: {end - startproj}\n')
    
#     ### STEP 2: Make the grid
#     start = time.time()
    
#     lc.makegrid()

#     end = time.time()
    
#     print(f'Grid created, time elapsed: {end - start}\n')
    
#     for idx_bool in lc.grid_dict['idx_cells']:

#         try: 

#             # Calculate height statistics, and return an array of the point heights
#             perc, heights = calcPercentileHeights(points=lc.las.points[idx_bool],
#                                                   groundthres=groundthreshold,
#                                                   returnHeights=True,
#                                                   heightcol=heightcol)
            
#             percdict[idx_bool] = perc
#             heightdict[idx_bool] = heights
            
#         except Exception as e:

#             print(f"Percentile Calc. - {e.__class__} for {lc.lasf}: \n")
#             print(f"\t{e}\n")


#         try:

#             # Compute complexity metrics
#             complexity = canopyLayerMetrics(h=heights,
#                                             hmax=stackheight,
#                                             step=verticalres,
#                                             groundthres=groundthreshold,
#                                             smoothsigma=0.5)
            
#             complexdict[idx_bool] = complexity
            
#         except Exception as e:

#             print(f"Complexity Calc. - {e.__class__} for {lc.lasf}: \n")
#             print(f"\t{e}\n")
